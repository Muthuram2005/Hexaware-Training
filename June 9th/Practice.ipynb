# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
.appName("RDD")\
.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ec9dda5e3816:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>RDD</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
numbers = [10, 20, 30, 40, 50]
rdd = spark.sparkContext.parallelize(numbers)
print(rdd.collect())
# Out:
# [10, 20, 30, 40, 50]

# %%
rdd.count()
# Out:
# 5

# %%
rdd.take(3)
# Out:
# [10, 20, 30]

# %%
numbers = [10, 20, 30, 40, 50]
rdd = spark.sparkContext.parallelize(numbers)
result = rdd.map(lambda x : x * 10)
print(result.collect())
# Out:
# [100, 200, 300, 400, 500]

# %%
numbers = [1, 2, 3, 4, 5]
rdd = spark.sparkContext.parallelize(numbers)
result = rdd.map(lambda x : x * x)
print(result.collect())
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
rdd = spark.sparkContext.parallelize(numbers)
result = rdd.filter(lambda x : x % 2 == 0)
print(result.collect())
# Out:
# [2, 4, 6, 8]

# %%
numbers = [10, 20, 20, 30, 40, 40, 50, 50]
rdd = spark.sparkContext.parallelize(numbers)
result = rdd.distinct()
print(result.collect())
# Out:
# [10, 20, 30, 40, 50]

# %%
rdd1 = spark.sparkContext.parallelize([10, 20, 30])
rdd2 = spark.sparkContext.parallelize([40, 50, 60])
result = rdd1.union(rdd2)
print(result.collect())
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
numbers = [40, 70, 30, 80, 50, 20, 60 ,10]
rdd = spark.sparkContext.parallelize(numbers)
result = rdd.sortBy(lambda x : x)
print(result.collect())
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
numbers = [10, 20, 30, 40]
rdd = spark.sparkContext.parallelize(numbers)
result = rdd.reduce(lambda x,y : x + y)
print(result)
# Out:
# 100
