# %% [markdown]
# **Dataset 1: stores.csv**

# %%
stores_data = """store_id,store_name,city,state,store_type,manager_name
S101,Metro Mart Hyderabad,Hyderabad,Telangana,Supermarket,Rahul Sharma
S102,Metro Mart Bangalore,Bangalore,Karnataka,Supermarket,Priya Reddy
S103,Metro Mart Mumbai,Mumbai,Maharashtra,Hypermarket,Amit Kumar
S104,Metro Mart Chennai,Chennai,Tamil Nadu,Supermarket,Sneha Patel
S105,Metro Mart Delhi,Delhi,Delhi,Hypermarket,Farhan Ali
S106,Metro Mart Pune,Pune,Maharashtra,Mini Store,Neha Singh
S107,Metro Mart Kochi,Kochi,Kerala,Mini Store,Arjun Verma
S108,Metro Mart Jaipur,Jaipur,Rajasthan,Supermarket,Meera Nair"""

with open("stores.csv", "w") as f:
    f.write(stores_data)

print("stores.csv created successfully!")
# Out:
# stores.csv created successfully!

# %% [markdown]
# **Dataset 2: products.csv**

# %%
products_data = """product_id,product_name,category,brand,supplier_id,unit_price
P101,Laptop,Electronics,Lenovo,S201,65000
P102,Mobile,Electronics,Samsung,S202,25000
P103,Television,Electronics,LG,S203,45000
P104,Office Chair,Furniture,Featherlite,S204,7000
P105,Study Table,Furniture,Urban Ladder,S204,12000
P106,Shoes,Fashion,Nike,S205,4500
P107,Watch,Fashion,Fastrack,S206,8000
P108,Backpack,Fashion,Wildcraft,S206,2500
P109,Refrigerator,Electronics,Whirlpool,S203,38000
P110,Sofa,Furniture,Godrej,S204,32000
P111,Headphones,Electronics,Sony,S999,3000
P112,T-Shirt,Fashion,Puma,,1500"""

with open("products.csv", "w") as f:
    f.write(products_data)

print("products.csv created successfully!")
# Out:
# products.csv created successfully!

# %% [markdown]
# **Dataset 3: inventory.csv**

# %%
inventory_data = """inventory_id,store_id,product_id,stock_quantity,reorder_level,last_update
I1001,S101,P101,10,5,2026-01-10
I1002,S101,P102,25,10,2026-01-10
I1003,S101,P104,3,5,2026-01-11
I1004,S102,P101,8,5,2026-01-12
I1005,S102,P103,5,4,2026-01-12
I1006,S103,P105,2,5,2026-01-13
I1007,S103,P106,30,10,2026-01-14
I1008,S104,P107,4,5,2026-01-15
I1009,S105,P108,50,20,2026-01-15
I1010,S106,P109,,6,2026-01-16
I1011,S107,P110,1,3,2026-01-17
I1012,S108,P120,12,5,2026-01-18"""

with open("inventory.csv", "w") as f:
    f.write(inventory_data)

print("inventory.csv created successfully!")
# Out:
# inventory.csv created successfully!

# %% [markdown]
# **Dataset 4: sales.csv**

# %%
sales_data = """sale_id,store_id,product_id,sale_date,quantity_sold,sale_amount,payment_mode
SA1001,S101,P101,2026-01-10,1,65000,UPI
SA1002,S101,P102,2026-01-10,2,50000,Card
SA1003,S102,P101,2026-01-11,1,65000,UPI
SA1004,S103,P106,2026-01-12,4,18000,Cash
SA1005,S104,P107,2026-01-12,1,8000,Card
SA1006,S105,P108,2026-01-13,5,12500,UPI
SA1007,S106,P109,2026-01-14,1,38000,Card
SA1008,S107,P110,2026-01-15,1,32000,UPI
SA1009,S108,P120,2026-01-15,2,10000,Cash
SA1010,S101,P104,2026-01-16,2,14000,
SA1011,S102,P103,2026-01-17,1,,UPI
SA1012,S103,P105,2026-01-18,1,12000,Card
SA1013,S104,P107,2026-02-01,2,16000,UPI
SA1014,S105,P108,2026-02-02,3,7500,Cash
SA1015,S101,P102,2026-02-03,1,25000,Card"""

with open("sales.csv", "w") as f:
    f.write(sales_data)

print("sales.csv created successfully!")
# Out:
# sales.csv created successfully!

# %% [markdown]
# **Dataset 5: suppliers.json**

# %%
import json

suppliers = [
    {
        "supplier_id": "S201",
        "supplier_name": "TechSource India",
        "city": "Hyderabad",
        "rating": 4.5,
        "contact": {
            "phone": "9876500011",
            "email": "techsource@mail.com"
        }
    },
    {
        "supplier_id": "S202",
        "supplier_name": "MobileWorld Distributors",
        "city": "Bangalore",
        "rating": 4.2,
        "contact": {
            "phone": None,
            "email": "mobileworld@mail.com"
        }
    },
    {
        "supplier_id": "S203",
        "supplier_name": "HomeTech Supply",
        "city": "Mumbai",
        "rating": 4.4,
        "contact": {
            "phone": "9876500013",
            "email": None
        }
    },
    {
        "supplier_id": "S204",
        "supplier_name": "Urban Furniture Co",
        "city": "Delhi",
        "rating": 4.0,
        "contact": {
            "phone": "9876500014",
            "email": "urban@mail.com"
        }
    },
    {
        "supplier_id": "S205",
        "supplier_name": "Fashion Direct",
        "city": "Pune",
        "rating": 3.8,
        "contact": {
            "phone": None,
            "email": None
        }
    }
]

with open("suppliers.json", "w") as f:
    json.dump(suppliers, f, indent=4)

print("suppliers.json created successfully!")
# Out:
# suppliers.json created successfully!

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("Capstone Project 2").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://d77b59747943:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Capstone Project 2</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# **Ingestion**

# %%
#1
stores = spark.read.csv("stores.csv",header=True,inferSchema=True)
stores.show()
# Out:
# +--------+--------------------+---------+-----------+-----------+------------+
# |store_id|          store_name|     city|      state| store_type|manager_name|
# +--------+--------------------+---------+-----------+-----------+------------+
# |    S101|Metro Mart Hyderabad|Hyderabad|  Telangana|Supermarket|Rahul Sharma|
# |    S102|Metro Mart Bangalore|Bangalore|  Karnataka|Supermarket| Priya Reddy|
# |    S103|   Metro Mart Mumbai|   Mumbai|Maharashtra|Hypermarket|  Amit Kumar|
# |    S104|  Metro Mart Chennai|  Chennai| Tamil Nadu|Supermarket| Sneha Patel|
# |    S105|    Metro Mart Delhi|    Delhi|      Delhi|Hypermarket|  Farhan Ali|
# |    S106|     Metro Mart Pune|     Pune|Maharashtra| Mini Store|  Neha Singh|
# |    S107|    Metro Mart Kochi|    Kochi|     Kerala| Mini Store| Arjun Verma|
# |    S108|   Metro Mart Jaipur|   Jaipur|  Rajasthan|Supermarket|  Meera Nair|
# +--------+--------------------+---------+-----------+-----------+------------+

# %%
#2
products = spark.read.csv("products.csv",header=True,inferSchema=True)
products.show()
# Out:
# +----------+------------+-----------+------------+-----------+----------+
# |product_id|product_name|   category|       brand|supplier_id|unit_price|
# +----------+------------+-----------+------------+-----------+----------+
# |      P101|      Laptop|Electronics|      Lenovo|       S201|     65000|
# |      P102|      Mobile|Electronics|     Samsung|       S202|     25000|
# |      P103|  Television|Electronics|          LG|       S203|     45000|
# |      P104|Office Chair|  Furniture| Featherlite|       S204|      7000|
# |      P105| Study Table|  Furniture|Urban Ladder|       S204|     12000|
# |      P106|       Shoes|    Fashion|        Nike|       S205|      4500|
# |      P107|       Watch|    Fashion|    Fastrack|       S206|      8000|
# |      P108|    Backpack|    Fashion|   Wildcraft|       S206|      2500|
# |      P109|Refrigerator|Electronics|   Whirlpool|       S203|     38000|
# |      P110|        Sofa|  Furniture|      Godrej|       S204|     32000|
# ...

# %%
#3
inventory = spark.read.csv("inventory.csv",header=True,inferSchema=True)
inventory.show()
# Out:
# +------------+--------+----------+--------------+-------------+-----------+
# |inventory_id|store_id|product_id|stock_quantity|reorder_level|last_update|
# +------------+--------+----------+--------------+-------------+-----------+
# |       I1001|    S101|      P101|            10|            5| 2026-01-10|
# |       I1002|    S101|      P102|            25|           10| 2026-01-10|
# |       I1003|    S101|      P104|             3|            5| 2026-01-11|
# |       I1004|    S102|      P101|             8|            5| 2026-01-12|
# |       I1005|    S102|      P103|             5|            4| 2026-01-12|
# |       I1006|    S103|      P105|             2|            5| 2026-01-13|
# |       I1007|    S103|      P106|            30|           10| 2026-01-14|
# |       I1008|    S104|      P107|             4|            5| 2026-01-15|
# |       I1009|    S105|      P108|            50|           20| 2026-01-15|
# ...

# %%
#4
sales = spark.read.csv("sales.csv",header=True,inferSchema=True)
sales.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|
# +-------+--------+----------+----------+-------------+-----------+------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|
# | SA1005|    S104|      P107|2026-01-12|            1|       8000|        Card|
# | SA1006|    S105|      P108|2026-01-13|            5|      12500|         UPI|
# | SA1007|    S106|      P109|2026-01-14|            1|      38000|        Card|
# | SA1008|    S107|      P110|2026-01-15|            1|      32000|         UPI|
# | SA1009|    S108|      P120|2026-01-15|            2|      10000|        Cash|
# ...

# %%
#5
suppliers = spark.read.option("multiline","true").json("suppliers.json")
suppliers.show(truncate=False)
# Out:
# +---------+---------------------------------+------+-----------+------------------------+
# |city     |contact                          |rating|supplier_id|supplier_name           |
# +---------+---------------------------------+------+-----------+------------------------+
# |Hyderabad|{techsource@mail.com, 9876500011}|4.5   |S201       |TechSource India        |
# |Bangalore|{mobileworld@mail.com, NULL}     |4.2   |S202       |MobileWorld Distributors|
# |Mumbai   |{NULL, 9876500013}               |4.4   |S203       |HomeTech Supply         |
# |Delhi    |{urban@mail.com, 9876500014}     |4.0   |S204       |Urban Furniture Co      |
# |Pune     |{NULL, NULL}                     |3.8   |S205       |Fashion Direct          |
# +---------+---------------------------------+------+-----------+------------------------+

# %%
#6
stores.printSchema()
products.printSchema()
inventort.printSchema()
sales.printSchema()
suppliers.printSchema()
# Out:
# root
#  |-- store_id: string (nullable = true)
#  |-- store_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- store_type: string (nullable = true)
#  |-- manager_name: string (nullable = true)
#
# root
#  |-- product_id: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- supplier_id: string (nullable = true)
#  |-- unit_price: integer (nullable = true)
#
# root
#  |-- inventory_id: string (nullable = true)
#  |-- store_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- stock_quantity: integer (nullable = true)
#  |-- reorder_level: integer (nullable = true)
#  |-- last_update: date (nullable = true)
#
# root
#  |-- sale_id: string (nullable = true)
#  |-- store_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- sale_date: date (nullable = true)
# ...

# %%
#7
print(stores.count())
print(products.count())
print(inventory.count())
print(sales.count())
print(suppliers.count())
# Out:
# 8
# 12
# 12
# 15
# 5

# %%
#8
stores.write.mode("overwrite").parquet("bronze/stores")
products.write.mode("overwrite").parquet("bronze/products")
inventory.write.mode("overwrite").parquet("bronze/inventory")
sales.write.mode("overwrite").parquet("bronze/sales")
suppliers.write.mode("overwrite").parquet("bronze/suppliers")

stores_bronze = spark.read.parquet("bronze/stores")
stores_bronze.show()
products_bronze = spark.read.parquet("bronze/products")
products_bronze.show()
inventory_bronze = spark.read.parquet("bronze/inventory")
inventory_bronze.show()
sales_bronze = spark.read.parquet("bronze/sales")
sales_bronze.show()
suppliers_bronze = spark.read.parquet("bronze/suppliers")
suppliers_bronze.show(truncate=False)
# Out:
# +--------+--------------------+---------+-----------+-----------+------------+
# |store_id|          store_name|     city|      state| store_type|manager_name|
# +--------+--------------------+---------+-----------+-----------+------------+
# |    S101|Metro Mart Hyderabad|Hyderabad|  Telangana|Supermarket|Rahul Sharma|
# |    S102|Metro Mart Bangalore|Bangalore|  Karnataka|Supermarket| Priya Reddy|
# |    S103|   Metro Mart Mumbai|   Mumbai|Maharashtra|Hypermarket|  Amit Kumar|
# |    S104|  Metro Mart Chennai|  Chennai| Tamil Nadu|Supermarket| Sneha Patel|
# |    S105|    Metro Mart Delhi|    Delhi|      Delhi|Hypermarket|  Farhan Ali|
# |    S106|     Metro Mart Pune|     Pune|Maharashtra| Mini Store|  Neha Singh|
# |    S107|    Metro Mart Kochi|    Kochi|     Kerala| Mini Store| Arjun Verma|
# |    S108|   Metro Mart Jaipur|   Jaipur|  Rajasthan|Supermarket|  Meera Nair|
# +--------+--------------------+---------+-----------+-----------+------------+
#
# ...

# %% [markdown]
# **Data Cleaning**

# %%
#9
products.filter(col("supplier_id").isNull()).show()
# Out:
# +----------+------------+--------+-----+-----------+----------+
# |product_id|product_name|category|brand|supplier_id|unit_price|
# +----------+------------+--------+-----+-----------+----------+
# |      P112|     T-Shirt| Fashion| Puma|       NULL|      1500|
# +----------+------------+--------+-----+-----------+----------+

# %%
#10
inventory.filter(col("stock_quantity").isNull()).show()
# Out:
# +------------+--------+----------+--------------+-------------+-----------+
# |inventory_id|store_id|product_id|stock_quantity|reorder_level|last_update|
# +------------+--------+----------+--------------+-------------+-----------+
# |       I1010|    S106|      P109|          NULL|            6| 2026-01-16|
# +------------+--------+----------+--------------+-------------+-----------+

# %%
#11
sales.filter(col("sale_amount").isNull()).show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|
# +-------+--------+----------+----------+-------------+-----------+------------+
# | SA1011|    S102|      P103|2026-01-17|            1|       NULL|         UPI|
# +-------+--------+----------+----------+-------------+-----------+------------+

# %%
#12
sales.filter(col("payment_mode").isNull()).show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|
# +-------+--------+----------+----------+-------------+-----------+------------+
# | SA1010|    S101|      P104|2026-01-16|            2|      14000|        NULL|
# +-------+--------+----------+----------+-------------+-----------+------------+

# %%
#13
inventory = inventory.fillna({"stock_quantity":0})
inventory.show()
# Out:
# +------------+--------+----------+--------------+-------------+-----------+
# |inventory_id|store_id|product_id|stock_quantity|reorder_level|last_update|
# +------------+--------+----------+--------------+-------------+-----------+
# |       I1001|    S101|      P101|            10|            5| 2026-01-10|
# |       I1002|    S101|      P102|            25|           10| 2026-01-10|
# |       I1003|    S101|      P104|             3|            5| 2026-01-11|
# |       I1004|    S102|      P101|             8|            5| 2026-01-12|
# |       I1005|    S102|      P103|             5|            4| 2026-01-12|
# |       I1006|    S103|      P105|             2|            5| 2026-01-13|
# |       I1007|    S103|      P106|            30|           10| 2026-01-14|
# |       I1008|    S104|      P107|             4|            5| 2026-01-15|
# |       I1009|    S105|      P108|            50|           20| 2026-01-15|
# ...

# %%
#14
sales = sales.fillna({"sale_amount":0})
sales.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|
# +-------+--------+----------+----------+-------------+-----------+------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|
# | SA1005|    S104|      P107|2026-01-12|            1|       8000|        Card|
# | SA1006|    S105|      P108|2026-01-13|            5|      12500|         UPI|
# | SA1007|    S106|      P109|2026-01-14|            1|      38000|        Card|
# | SA1008|    S107|      P110|2026-01-15|            1|      32000|         UPI|
# | SA1009|    S108|      P120|2026-01-15|            2|      10000|        Cash|
# ...

# %%
#15
sales = sales.fillna({"payment_mode":"Not Provided"})
sales.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|
# +-------+--------+----------+----------+-------------+-----------+------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|
# | SA1005|    S104|      P107|2026-01-12|            1|       8000|        Card|
# | SA1006|    S105|      P108|2026-01-13|            5|      12500|         UPI|
# | SA1007|    S106|      P109|2026-01-14|            1|      38000|        Card|
# | SA1008|    S107|      P110|2026-01-15|            1|      32000|         UPI|
# | SA1009|    S108|      P120|2026-01-15|            2|      10000|        Cash|
# ...

# %%
#16
products =  products.fillna({"supplier_id":"UNKNOWN"})
products.show()
# Out:
# +----------+------------+-----------+------------+-----------+----------+
# |product_id|product_name|   category|       brand|supplier_id|unit_price|
# +----------+------------+-----------+------------+-----------+----------+
# |      P101|      Laptop|Electronics|      Lenovo|       S201|     65000|
# |      P102|      Mobile|Electronics|     Samsung|       S202|     25000|
# |      P103|  Television|Electronics|          LG|       S203|     45000|
# |      P104|Office Chair|  Furniture| Featherlite|       S204|      7000|
# |      P105| Study Table|  Furniture|Urban Ladder|       S204|     12000|
# |      P106|       Shoes|    Fashion|        Nike|       S205|      4500|
# |      P107|       Watch|    Fashion|    Fastrack|       S206|      8000|
# |      P108|    Backpack|    Fashion|   Wildcraft|       S206|      2500|
# |      P109|Refrigerator|Electronics|   Whirlpool|       S203|     38000|
# |      P110|        Sofa|  Furniture|      Godrej|       S204|     32000|
# ...

# %%
#17
products = products.withColumn("data_quality_status", when(col("supplier_id")=="UNKNOWN","Invalid").otherwise("Valid"))
inventory = inventory.withColumn("data_quality_status",when(col("stock_quantity")==0,"Invalid").otherwise("Valid"))
sales = sales.withColumn("data_quality_status",when(col("sale_amount")==0,"Invalid").otherwise("Valid"))

products.show()
inventory.show()
sales.show()
# Out:
# +----------+------------+-----------+------------+-----------+----------+-------------------+
# |product_id|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|
# +----------+------------+-----------+------------+-----------+----------+-------------------+
# |      P101|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|
# |      P102|      Mobile|Electronics|     Samsung|       S202|     25000|              Valid|
# |      P103|  Television|Electronics|          LG|       S203|     45000|              Valid|
# |      P104|Office Chair|  Furniture| Featherlite|       S204|      7000|              Valid|
# |      P105| Study Table|  Furniture|Urban Ladder|       S204|     12000|              Valid|
# |      P106|       Shoes|    Fashion|        Nike|       S205|      4500|              Valid|
# |      P107|       Watch|    Fashion|    Fastrack|       S206|      8000|              Valid|
# ...

# %%
#18
products.write.mode("overwrite").parquet("silver/products")
inventory.write.mode("overwrite").parquet("silver/inventory")
sales.write.mode("overwrite").parquet("silver/sales")

products_silver = spark.read.parquet("silver/products")
products_silver.show()
inventory_silver = spark.read.parquet("silver/inventory")
inventory_silver.show()
sales_silver = spark.read.parquet("silver/sales")
sales_silver.show()
# Out:
# +----------+------------+-----------+------------+-----------+----------+-------------------+
# |product_id|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|
# +----------+------------+-----------+------------+-----------+----------+-------------------+
# |      P101|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|
# |      P102|      Mobile|Electronics|     Samsung|       S202|     25000|              Valid|
# |      P103|  Television|Electronics|          LG|       S203|     45000|              Valid|
# |      P104|Office Chair|  Furniture| Featherlite|       S204|      7000|              Valid|
# |      P105| Study Table|  Furniture|Urban Ladder|       S204|     12000|              Valid|
# |      P106|       Shoes|    Fashion|        Nike|       S205|      4500|              Valid|
# |      P107|       Watch|    Fashion|    Fastrack|       S206|      8000|              Valid|
# ...

# %% [markdown]
# **JSON Flattening**

# %%
#19
suppliers_flat = suppliers.select("supplier_id","supplier_name","city","rating",col("contact.phone").alias("phone"),col("contact.email").alias("email"))
suppliers_flat.show()
# Out:
# +-----------+--------------------+---------+------+----------+--------------------+
# |supplier_id|       supplier_name|     city|rating|     phone|               email|
# +-----------+--------------------+---------+------+----------+--------------------+
# |       S201|    TechSource India|Hyderabad|   4.5|9876500011| techsource@mail.com|
# |       S202|MobileWorld Distr...|Bangalore|   4.2|      NULL|mobileworld@mail.com|
# |       S203|     HomeTech Supply|   Mumbai|   4.4|9876500013|                NULL|
# |       S204|  Urban Furniture Co|    Delhi|   4.0|9876500014|      urban@mail.com|
# |       S205|      Fashion Direct|     Pune|   3.8|      NULL|                NULL|
# +-----------+--------------------+---------+------+----------+--------------------+

# %%
#20
suppliers_flat.select("phone").show()
# Out:
# +----------+
# |     phone|
# +----------+
# |9876500011|
# |      NULL|
# |9876500013|
# |9876500014|
# |      NULL|
# +----------+

# %%
#21
suppliers_flat.select("email").show()
# Out:
# +--------------------+
# |               email|
# +--------------------+
# | techsource@mail.com|
# |mobileworld@mail.com|
# |                NULL|
# |      urban@mail.com|
# |                NULL|
# +--------------------+

# %%
#22
suppliers_flat = suppliers_flat.fillna({"phone": "Not Provided"})
suppliers_flat.show()
# Out:
# +-----------+--------------------+---------+------+------------+--------------------+
# |supplier_id|       supplier_name|     city|rating|       phone|               email|
# +-----------+--------------------+---------+------+------------+--------------------+
# |       S201|    TechSource India|Hyderabad|   4.5|  9876500011| techsource@mail.com|
# |       S202|MobileWorld Distr...|Bangalore|   4.2|Not Provided|mobileworld@mail.com|
# |       S203|     HomeTech Supply|   Mumbai|   4.4|  9876500013|                NULL|
# |       S204|  Urban Furniture Co|    Delhi|   4.0|  9876500014|      urban@mail.com|
# |       S205|      Fashion Direct|     Pune|   3.8|Not Provided|                NULL|
# +-----------+--------------------+---------+------+------------+--------------------+

# %%
#23
suppliers_flat = suppliers_flat.fillna({"email": "Not Provided"})
suppliers_flat.show()
# Out:
# +-----------+--------------------+---------+------+------------+--------------------+
# |supplier_id|       supplier_name|     city|rating|       phone|               email|
# +-----------+--------------------+---------+------+------------+--------------------+
# |       S201|    TechSource India|Hyderabad|   4.5|  9876500011| techsource@mail.com|
# |       S202|MobileWorld Distr...|Bangalore|   4.2|Not Provided|mobileworld@mail.com|
# |       S203|     HomeTech Supply|   Mumbai|   4.4|  9876500013|        Not Provided|
# |       S204|  Urban Furniture Co|    Delhi|   4.0|  9876500014|      urban@mail.com|
# |       S205|      Fashion Direct|     Pune|   3.8|Not Provided|        Not Provided|
# +-----------+--------------------+---------+------+------------+--------------------+

# %%
#24
suppliers_flat.write.mode("overwrite").parquet("silver/suppliers")
suppliers_silver = spark.read.parquet("silver/suppliers")
suppliers_silver.show()
# Out:
# +-----------+--------------------+---------+------+------------+--------------------+
# |supplier_id|       supplier_name|     city|rating|       phone|               email|
# +-----------+--------------------+---------+------+------------+--------------------+
# |       S201|    TechSource India|Hyderabad|   4.5|  9876500011| techsource@mail.com|
# |       S202|MobileWorld Distr...|Bangalore|   4.2|Not Provided|mobileworld@mail.com|
# |       S203|     HomeTech Supply|   Mumbai|   4.4|  9876500013|        Not Provided|
# |       S204|  Urban Furniture Co|    Delhi|   4.0|  9876500014|      urban@mail.com|
# |       S205|      Fashion Direct|     Pune|   3.8|Not Provided|        Not Provided|
# +-----------+--------------------+---------+------+------------+--------------------+

# %% [markdown]
# **Joins**

# %%
#25
prod_supp = products.join(suppliers_flat, "supplier_id","left")
prod_supp.show()
# Out:
# +-----------+----------+------------+-----------+------------+----------+-------------------+--------------------+---------+------+------------+--------------------+
# |supplier_id|product_id|product_name|   category|       brand|unit_price|data_quality_status|       supplier_name|     city|rating|       phone|               email|
# +-----------+----------+------------+-----------+------------+----------+-------------------+--------------------+---------+------+------------+--------------------+
# |       S201|      P101|      Laptop|Electronics|      Lenovo|     65000|              Valid|    TechSource India|Hyderabad|   4.5|  9876500011| techsource@mail.com|
# |       S202|      P102|      Mobile|Electronics|     Samsung|     25000|              Valid|MobileWorld Distr...|Bangalore|   4.2|Not Provided|mobileworld@mail.com|
# ...

# %%
#26
inve_prod = inventory.join(products, "product_id","left")
inve_prod.show()
# Out:
# +----------+------------+--------+--------------+-------------+-----------+-------------------+------------+-----------+------------+-----------+----------+-------------------+
# |product_id|inventory_id|store_id|stock_quantity|reorder_level|last_update|data_quality_status|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|
# +----------+------------+--------+--------------+-------------+-----------+-------------------+------------+-----------+------------+-----------+----------+-------------------+
# |      P101|       I1001|    S101|            10|            5| 2026-01-10|              Valid|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|
# |      P102|       I1002|    S101|            25|           10| 2026-01-10|              Valid|      Mobile|Electronics|     Samsung|       S202|     25000|              Valid|
# ...

# %%
#27
sales_stores = sales.join(stores, "store_id","left")
sales_stores.show()
# Out:
# +--------+-------+----------+----------+-------------+-----------+------------+-------------------+--------------------+---------+-----------+-----------+------------+
# |store_id|sale_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|          store_name|     city|      state| store_type|manager_name|
# +--------+-------+----------+----------+-------------+-----------+------------+-------------------+--------------------+---------+-----------+-----------+------------+
# |    S101| SA1001|      P101|2026-01-10|            1|      65000|         UPI|              Valid|Metro Mart Hyderabad|Hyderabad|  Telangana|Supermarket|Rahul Sharma|
# |    S101| SA1002|      P102|2026-01-10|            2|      50000|        Card|              Valid|Metro Mart Hyderabad|Hyderabad|  Telangana|Supermarket|Rahul Sharma|
# ...

# %%
#28
sales_prod = sales.join(products, "product_id","left")
sales_prod.show()
# Out:
# +----------+-------+--------+----------+-------------+-----------+------------+-------------------+------------+-----------+------------+-----------+----------+-------------------+
# |product_id|sale_id|store_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|
# +----------+-------+--------+----------+-------------+-----------+------------+-------------------+------------+-----------+------------+-----------+----------+-------------------+
# |      P101| SA1001|    S101|2026-01-10|            1|      65000|         UPI|              Valid|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|
# |      P102| SA1002|    S101|2026-01-10|            2|      50000|        Card|              Valid|      Mobile|Electronics|     Samsung|       S202|     25000|              Valid|
# ...

# %%
#29
retail = sales.join(stores,"store_id","left").join(products,"product_id","left")
retail.show()
# Out:
# +----------+--------+-------+----------+-------------+-----------+------------+-------------------+--------------------+---------+-----------+-----------+------------+------------+-----------+------------+-----------+----------+-------------------+
# |product_id|store_id|sale_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|          store_name|     city|      state| store_type|manager_name|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|
# +----------+--------+-------+----------+-------------+-----------+------------+-------------------+--------------------+---------+-----------+-----------+------------+------------+-----------+------------+-----------+----------+-------------------+
# ...

# %%
#30
products.join(suppliers_flat,"supplier_id","left_anti").show()
# Out:
# +-----------+----------+------------+-----------+---------+----------+-------------------+
# |supplier_id|product_id|product_name|   category|    brand|unit_price|data_quality_status|
# +-----------+----------+------------+-----------+---------+----------+-------------------+
# |       S206|      P107|       Watch|    Fashion| Fastrack|      8000|              Valid|
# |       S206|      P108|    Backpack|    Fashion|Wildcraft|      2500|              Valid|
# |       S999|      P111|  Headphones|Electronics|     Sony|      3000|              Valid|
# |    UNKNOWN|      P112|     T-Shirt|    Fashion|     Puma|      1500|            Invalid|
# +-----------+----------+------------+-----------+---------+----------+-------------------+

# %%
#31
inventory.join(products,"product_id","left_anti").show()
# Out:
# +----------+------------+--------+--------------+-------------+-----------+-------------------+
# |product_id|inventory_id|store_id|stock_quantity|reorder_level|last_update|data_quality_status|
# +----------+------------+--------+--------------+-------------+-----------+-------------------+
# |      P120|       I1012|    S108|            12|            5| 2026-01-18|              Valid|
# +----------+------------+--------+--------------+-------------+-----------+-------------------+

# %%
#32
sales.join(products,"product_id","left_anti").show()
# Out:
# +----------+-------+--------+----------+-------------+-----------+------------+-------------------+
# |product_id|sale_id|store_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|
# +----------+-------+--------+----------+-------------+-----------+------------+-------------------+
# |      P120| SA1009|    S108|2026-01-15|            2|      10000|        Cash|              Valid|
# +----------+-------+--------+----------+-------------+-----------+------------+-------------------+

# %%
#33
sales.join(stores,"store_id","left_anti").show()
# Out:
# +--------+-------+----------+---------+-------------+-----------+------------+-------------------+
# |store_id|sale_id|product_id|sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|
# +--------+-------+----------+---------+-------------+-----------+------------+-------------------+
# +--------+-------+----------+---------+-------------+-----------+------------+-------------------+

# %% [markdown]
# **Transformations**

# %%
#34
inve_prod = inve_prod.withColumn("stock_status",when(col("stock_quantity") <= col("reorder_level"),"Reorder Required").otherwise("Sufficient Stock"))
inve_prod.show()
# Out:
# +----------+------------+--------+--------------+-------------+-----------+-------------------+------------+-----------+------------+-----------+----------+-------------------+----------------+
# |product_id|inventory_id|store_id|stock_quantity|reorder_level|last_update|data_quality_status|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|    stock_status|
# +----------+------------+--------+--------------+-------------+-----------+-------------------+------------+-----------+------------+-----------+----------+-------------------+----------------+
# |      P101|       I1001|    S101|            10|            5| 2026-01-10|              Valid|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|Sufficient Stock|
# |      P102|       I1002|    S101|            25|           10| 2026-01-10|              Valid|      Mobile|Electronics|     Samsung|       S202|     25000|              Valid|Sufficient Stock|
# ...

# %%
#35
products = products.withColumn("price_category",when(col("unit_price")>=50000,"Premium").when(col("unit_price")>=10000,"Standard").otherwise("Budget"))
products.show()
# Out:
# +----------+------------+-----------+------------+-----------+----------+-------------------+--------------+
# |product_id|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|price_category|
# +----------+------------+-----------+------------+-----------+----------+-------------------+--------------+
# |      P101|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|       Premium|
# |      P102|      Mobile|Electronics|     Samsung|       S202|     25000|              Valid|      Standard|
# |      P103|  Television|Electronics|          LG|       S203|     45000|              Valid|      Standard|
# |      P104|Office Chair|  Furniture| Featherlite|       S204|      7000|              Valid|        Budget|
# |      P105| Study Table|  Furniture|Urban Ladder|       S204|     12000|              Valid|      Standard|
# |      P106|       Shoes|    Fashion|        Nike|       S205|      4500|              Valid|        Budget|
# ...

# %%
#36
sales = sales.withColumn("revenue_category", when(col("sale_amount")>=50000,"High Revenue").when(col("sale_amount")>=15000,"Medium Revenue").otherwise("Low Revenue"))
sales.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|
# | SA1005|    S104|      P107|2026-01-12|            1|       8000|        Card|              Valid|     Low Revenue|
# ...

# %%
#37
sales = sales.withColumn("month", month("sale_date"))
sales.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|    1|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|    1|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|    1|
# | SA1005|    S104|      P107|2026-01-12|            1|       8000|        Card|              Valid|     Low Revenue|    1|
# ...

# %%
#38
sales = sales.withColumn("year", year("sale_date"))
sales.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|    1|2026|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|    1|2026|
# ...

# %%
#39
inve_prod = inve_prod.withColumn("inventory_value",col("stock_quantity") * col("unit_price"))
inve_prod.show()
# Out:
# +----------+------------+--------+--------------+-------------+-----------+-------------------+------------+-----------+------------+-----------+----------+-------------------+----------------+---------------+
# |product_id|inventory_id|store_id|stock_quantity|reorder_level|last_update|data_quality_status|product_name|   category|       brand|supplier_id|unit_price|data_quality_status|    stock_status|inventory_value|
# +----------+------------+--------+--------------+-------------+-----------+-------------------+------------+-----------+------------+-----------+----------+-------------------+----------------+---------------+
# |      P101|       I1001|    S101|            10|            5| 2026-01-10|              Valid|      Laptop|Electronics|      Lenovo|       S201|     65000|              Valid|Sufficient Stock|         650000|
# ...

# %%
#40
suppliers_flat = suppliers_flat.withColumn("supplier_quality", when(col("rating")>=4.5,"Excellent").when(col("rating")>=4.0,"Good").otherwise("Average"))
suppliers_flat.show()
# Out:
# +-----------+--------------------+---------+------+------------+--------------------+----------------+
# |supplier_id|       supplier_name|     city|rating|       phone|               email|supplier_quality|
# +-----------+--------------------+---------+------+------------+--------------------+----------------+
# |       S201|    TechSource India|Hyderabad|   4.5|  9876500011| techsource@mail.com|       Excellent|
# |       S202|MobileWorld Distr...|Bangalore|   4.2|Not Provided|mobileworld@mail.com|            Good|
# |       S203|     HomeTech Supply|   Mumbai|   4.4|  9876500013|        Not Provided|            Good|
# |       S204|  Urban Furniture Co|    Delhi|   4.0|  9876500014|      urban@mail.com|            Good|
# |       S205|      Fashion Direct|     Pune|   3.8|Not Provided|        Not Provided|         Average|
# +-----------+--------------------+---------+------+------------+--------------------+----------------+

# %% [markdown]
# **Aggregations**

# %%
#41
stores.groupBy("state").count().show()
# Out:
# +-----------+-----+
# |      state|count|
# +-----------+-----+
# |  Karnataka|    1|
# |     Kerala|    1|
# | Tamil Nadu|    1|
# |      Delhi|    1|
# |  Rajasthan|    1|
# |  Telangana|    1|
# |Maharashtra|    2|
# +-----------+-----+

# %%
#42
products.groupBy("category").count().show()
# Out:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# |    Fashion|    4|
# |Electronics|    5|
# |  Furniture|    3|
# +-----------+-----+

# %%
#43
products.groupBy("brand").count().show()
# Out:
# +------------+-----+
# |       brand|count|
# +------------+-----+
# |        Nike|    1|
# |        Sony|    1|
# |Urban Ladder|    1|
# |        Puma|    1|
# |      Lenovo|    1|
# | Featherlite|    1|
# |     Samsung|    1|
# |      Godrej|    1|
# |          LG|    1|
# |   Wildcraft|    1|
# |    Fastrack|    1|
# |   Whirlpool|    1|
# +------------+-----+

# %%
#44
inve_prod.groupBy("store_id").agg(sum("inventory_value").alias("total_inventory_value")).show()
# Out:
# +--------+---------------------+
# |store_id|total_inventory_value|
# +--------+---------------------+
# |    S105|               125000|
# |    S102|               745000|
# |    S106|                    0|
# |    S104|                32000|
# |    S107|                32000|
# |    S101|              1296000|
# |    S108|                 NULL|
# |    S103|               159000|
# +--------+---------------------+

# %%
#45
inve_prod.groupBy("category").agg(sum("inventory_value").alias("total_inventory_value")).show()
# Out:
# +-----------+---------------------+
# |   category|total_inventory_value|
# +-----------+---------------------+
# |    Fashion|               292000|
# |       NULL|                 NULL|
# |Electronics|              2020000|
# |  Furniture|                77000|
# +-----------+---------------------+

# %%
#46
inve_prod.filter(col("stock_status")=="Reorder Required").count()
# Out:
# 5

# %%
#47
sales.agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +-------------+
# |total_revenue|
# +-------------+
# |       373000|
# +-------------+

# %%
#48
retail.groupBy("store_id").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +--------+-------------+
# |store_id|total_revenue|
# +--------+-------------+
# |    S105|        20000|
# |    S102|        65000|
# |    S106|        38000|
# |    S104|        24000|
# |    S107|        32000|
# |    S101|       154000|
# |    S108|        10000|
# |    S103|        30000|
# +--------+-------------+

# %%
#49
retail.groupBy("city").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|        65000|
# |    Kochi|        32000|
# |  Chennai|        24000|
# |   Mumbai|        30000|
# |     Pune|        38000|
# |    Delhi|        20000|
# |Hyderabad|       154000|
# |   Jaipur|        10000|
# +---------+-------------+

# %%
#50
retail.groupBy("category").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# |    Fashion|        62000|
# |       NULL|        10000|
# |Electronics|       243000|
# |  Furniture|        58000|
# +-----------+-------------+

# %%
#51
retail.groupBy("product_name").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +------------+-------------+
# |product_name|total_revenue|
# +------------+-------------+
# |Office Chair|        14000|
# |        NULL|        10000|
# |Refrigerator|        38000|
# |      Laptop|       130000|
# |        Sofa|        32000|
# |    Backpack|        20000|
# |       Shoes|        18000|
# |      Mobile|        75000|
# |  Television|            0|
# | Study Table|        12000|
# |       Watch|        24000|
# +------------+-------------+

# %%
#52
sales.groupBy("payment_mode").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +------------+-------------+
# |payment_mode|total_revenue|
# +------------+-------------+
# |        Card|       133000|
# |        Cash|        35500|
# |Not Provided|        14000|
# |         UPI|       190500|
# +------------+-------------+

# %%
#53
retail.groupBy("product_name").sum("sale_amount").orderBy(desc("sum(sale_amount)")).show(1)
# Out:
# +------------+----------------+
# |product_name|sum(sale_amount)|
# +------------+----------------+
# |      Laptop|          130000|
# +------------+----------------+
# only showing top 1 row

# %%
#54
retail.groupBy("store_name").sum("sale_amount").orderBy(desc("sum(sale_amount)")).show(1)
# Out:
# +--------------------+----------------+
# |          store_name|sum(sale_amount)|
# +--------------------+----------------+
# |Metro Mart Hyderabad|          154000|
# +--------------------+----------------+
# only showing top 1 row

# %%
#55
retail.groupBy("category").sum("sale_amount").orderBy(desc("sum(sale_amount)")).show(1)
# Out:
# +-----------+----------------+
# |   category|sum(sale_amount)|
# +-----------+----------------+
# |Electronics|          243000|
# +-----------+----------------+
# only showing top 1 row

# %% [markdown]
# **Window Functions**

# %%
#56
from pyspark.sql.window import Window

w = Window.orderBy(desc("revenue"))
product_revenue = retail.groupBy("product_id").agg(sum("sale_amount").alias("revenue"))
product_revenue.withColumn("rank",rank().over(w)).show()
# Out:
# +----------+-------+----+
# |product_id|revenue|rank|
# +----------+-------+----+
# |      P101| 130000|   1|
# |      P102|  75000|   2|
# |      P109|  38000|   3|
# |      P110|  32000|   4|
# |      P107|  24000|   5|
# |      P108|  20000|   6|
# |      P106|  18000|   7|
# |      P104|  14000|   8|
# |      P105|  12000|   9|
# |      P120|  10000|  10|
# |      P103|      0|  11|
# +----------+-------+----+

# %%
#57
store_revenue = retail.groupBy("store_id").agg(sum("sale_amount").alias("revenue"))
store_revenue.withColumn("rank",rank().over(w)).show()
# Out:
# +--------+-------+----+
# |store_id|revenue|rank|
# +--------+-------+----+
# |    S101| 154000|   1|
# |    S102|  65000|   2|
# |    S106|  38000|   3|
# |    S107|  32000|   4|
# |    S103|  30000|   5|
# |    S104|  24000|   6|
# |    S105|  20000|   7|
# |    S108|  10000|   8|
# +--------+-------+----+

# %%
#58
w1 = Window.partitionBy("category").orderBy(desc("revenue"))
category_revenue = retail.groupBy("product_id","category").agg(sum("sale_amount").alias("revenue"))
category_revenue.withColumn("rank",rank().over(w1)).show()
# Out:
# +----------+-----------+-------+----+
# |product_id|   category|revenue|rank|
# +----------+-----------+-------+----+
# |      P120|       NULL|  10000|   1|
# |      P101|Electronics| 130000|   1|
# |      P102|Electronics|  75000|   2|
# |      P109|Electronics|  38000|   3|
# |      P103|Electronics|      0|   4|
# |      P107|    Fashion|  24000|   1|
# |      P108|    Fashion|  20000|   2|
# |      P106|    Fashion|  18000|   3|
# |      P110|  Furniture|  32000|   1|
# |      P104|  Furniture|  14000|   2|
# |      P105|  Furniture|  12000|   3|
# +----------+-----------+-------+----+

# %%
#59
category_revenue.withColumn("rank",rank().over(w1)).filter(col("rank")==1).show()
# Out:
# +----------+-----------+-------+----+
# |product_id|   category|revenue|rank|
# +----------+-----------+-------+----+
# |      P120|       NULL|  10000|   1|
# |      P101|Electronics| 130000|   1|
# |      P107|    Fashion|  24000|   1|
# |      P110|  Furniture|  32000|   1|
# +----------+-----------+-------+----+

# %%
#60
category_revenue.withColumn("rank",rank().over(w1)).filter(col("rank")<=3).show()
# Out:
# +----------+-----------+-------+----+
# |product_id|   category|revenue|rank|
# +----------+-----------+-------+----+
# |      P120|       NULL|  10000|   1|
# |      P101|Electronics| 130000|   1|
# |      P102|Electronics|  75000|   2|
# |      P109|Electronics|  38000|   3|
# |      P107|    Fashion|  24000|   1|
# |      P108|    Fashion|  20000|   2|
# |      P106|    Fashion|  18000|   3|
# |      P110|  Furniture|  32000|   1|
# |      P104|  Furniture|  14000|   2|
# |      P105|  Furniture|  12000|   3|
# +----------+-----------+-------+----+

# %%
#61
store_state = retail.groupBy("state","store_id").agg(sum("sale_amount").alias("revenue"))
w2 = Window.partitionBy("state").orderBy(desc("revenue"))
store_state.withColumn("rank",rank().over(w2)).filter(col("rank")==1).show()
# Out:
# +-----------+--------+-------+----+
# |      state|store_id|revenue|rank|
# +-----------+--------+-------+----+
# |      Delhi|    S105|  20000|   1|
# |  Karnataka|    S102|  65000|   1|
# |     Kerala|    S107|  32000|   1|
# |Maharashtra|    S106|  38000|   1|
# |  Rajasthan|    S108|  10000|   1|
# | Tamil Nadu|    S104|  24000|   1|
# |  Telangana|    S101| 154000|   1|
# +-----------+--------+-------+----+

# %%
#62
w3 = Window.orderBy("sale_date")
sales.withColumn("running_total",sum("sale_amount").over(w3)).show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+-------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|running_total|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+-------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|       115000|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|    1|2026|       115000|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|       180000|
# ...

# %%
#63
sales.withColumn("previous_sale",lag("sale_amount").over(w3)).show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+-------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|previous_sale|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+-------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|         NULL|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|    1|2026|        65000|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|        50000|
# ...

# %%
#64
sales.withColumn("next_sale",lead("sale_amount").over(w3)).show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+---------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|next_sale|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+---------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|    50000|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|    1|2026|    65000|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|    18000|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|    1|2026|     8000|
# ...

# %%
#65
sales.withColumn("previous_sale",lag("sale_amount").over(w3)).filter(col("sale_amount") > col("previous_sale")).show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+-------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|previous_sale|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+-------------+
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|        50000|
# | SA1006|    S105|      P108|2026-01-13|            5|      12500|         UPI|              Valid|     Low Revenue|    1|2026|         8000|
# | SA1007|    S106|      P109|2026-01-14|            1|      38000|        Card|              Valid|  Medium Revenue|    1|2026|        12500|
# ...

# %% [markdown]
# **Spark SQL**

# %%
#66
stores.createOrReplaceTempView("stores")
spark.sql("select * from stores").show()
products.createOrReplaceTempView("products")
spark.sql("select * from products").show()
inventory.createOrReplaceTempView("inventory")
spark.sql("select * from inventory").show()
sales.createOrReplaceTempView("sales")
spark.sql("select * from sales").show()
suppliers_flat.createOrReplaceTempView("suppliers")
spark.sql("select * from suppliers").show()
# Out:
# +--------+--------------------+---------+-----------+-----------+------------+
# |store_id|          store_name|     city|      state| store_type|manager_name|
# +--------+--------------------+---------+-----------+-----------+------------+
# |    S101|Metro Mart Hyderabad|Hyderabad|  Telangana|Supermarket|Rahul Sharma|
# |    S102|Metro Mart Bangalore|Bangalore|  Karnataka|Supermarket| Priya Reddy|
# |    S103|   Metro Mart Mumbai|   Mumbai|Maharashtra|Hypermarket|  Amit Kumar|
# |    S104|  Metro Mart Chennai|  Chennai| Tamil Nadu|Supermarket| Sneha Patel|
# |    S105|    Metro Mart Delhi|    Delhi|      Delhi|Hypermarket|  Farhan Ali|
# |    S106|     Metro Mart Pune|     Pune|Maharashtra| Mini Store|  Neha Singh|
# |    S107|    Metro Mart Kochi|    Kochi|     Kerala| Mini Store| Arjun Verma|
# |    S108|   Metro Mart Jaipur|   Jaipur|  Rajasthan|Supermarket|  Meera Nair|
# +--------+--------------------+---------+-----------+-----------+------------+
#
# ...

# %%
#67
spark.sql("SELECT * FROM sales").show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|    1|2026|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|    1|2026|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|    1|2026|
# ...

# %%
#68
spark.sql("SELECT category,COUNT(*) AS total_products FROM products GROUP BY category").show()
# Out:
# +-----------+--------------+
# |   category|total_products|
# +-----------+--------------+
# |    Fashion|             4|
# |Electronics|             5|
# |  Furniture|             3|
# +-----------+--------------+

# %%
#69
spark.sql("""SELECT st.store_id,st.store_name,SUM(sa.sale_amount) AS total_revenue FROM sales sa
JOIN stores st ON sa.store_id = st.store_id
GROUP BY st.store_id, st.store_name;""").show()
# Out:
# +--------+--------------------+-------------+
# |store_id|          store_name|total_revenue|
# +--------+--------------------+-------------+
# |    S105|    Metro Mart Delhi|        20000|
# |    S102|Metro Mart Bangalore|        65000|
# |    S101|Metro Mart Hyderabad|       154000|
# |    S104|  Metro Mart Chennai|        24000|
# |    S103|   Metro Mart Mumbai|        30000|
# |    S108|   Metro Mart Jaipur|        10000|
# |    S107|    Metro Mart Kochi|        32000|
# |    S106|     Metro Mart Pune|        38000|
# +--------+--------------------+-------------+

# %%
#70
spark.sql("""SELECT st.city, SUM(sa.sale_amount) AS total_revenue FROM sales sa
JOIN stores st ON sa.store_id = st.store_id
GROUP BY st.city;""").show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|        65000|
# |    Kochi|        32000|
# |  Chennai|        24000|
# |   Mumbai|        30000|
# |     Pune|        38000|
# |    Delhi|        20000|
# |Hyderabad|       154000|
# |   Jaipur|        10000|
# +---------+-------------+

# %%
#71
spark.sql("""SELECT i.store_id, i.product_id, p.product_name, i.stock_quantity, i.reorder_level FROM inventory i
JOIN products p ON i.product_id = p.product_id
WHERE i.stock_quantity <= i.reorder_level;""").show()
# Out:
# +--------+----------+------------+--------------+-------------+
# |store_id|product_id|product_name|stock_quantity|reorder_level|
# +--------+----------+------------+--------------+-------------+
# |    S101|      P104|Office Chair|             3|            5|
# |    S103|      P105| Study Table|             2|            5|
# |    S104|      P107|       Watch|             4|            5|
# |    S106|      P109|Refrigerator|             0|            6|
# |    S107|      P110|        Sofa|             1|            3|
# +--------+----------+------------+--------------+-------------+

# %%
#72
spark.sql("""SELECT sa.* FROM sales sa
LEFT JOIN products p ON sa.product_id = p.product_id
WHERE p.product_id IS NULL;""").show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|month|year|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+
# | SA1009|    S108|      P120|2026-01-15|            2|      10000|        Cash|              Valid|     Low Revenue|    1|2026|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+-----+----+

# %%
#73
spark.sql("""SELECT p.* FROM products p
LEFT JOIN suppliers s ON p.supplier_id = s.supplier_id
WHERE s.supplier_id IS NULL;""").show()
# Out:
# +----------+------------+-----------+---------+-----------+----------+-------------------+--------------+
# |product_id|product_name|   category|    brand|supplier_id|unit_price|data_quality_status|price_category|
# +----------+------------+-----------+---------+-----------+----------+-------------------+--------------+
# |      P107|       Watch|    Fashion| Fastrack|       S206|      8000|              Valid|        Budget|
# |      P108|    Backpack|    Fashion|Wildcraft|       S206|      2500|              Valid|        Budget|
# |      P111|  Headphones|Electronics|     Sony|       S999|      3000|              Valid|        Budget|
# |      P112|     T-Shirt|    Fashion|     Puma|    UNKNOWN|      1500|            Invalid|        Budget|
# +----------+------------+-----------+---------+-----------+----------+-------------------+--------------+

# %%
#74
spark.sql("""SELECT p.product_id, p.product_name, SUM(sa.sale_amount) AS total_revenue FROM sales sa
JOIN products p ON sa.product_id = p.product_id
GROUP BY p.product_id, p.product_name
ORDER BY total_revenue DESC
LIMIT 5;""").show()
# Out:
# +----------+------------+-------------+
# |product_id|product_name|total_revenue|
# +----------+------------+-------------+
# |      P101|      Laptop|       130000|
# |      P102|      Mobile|        75000|
# |      P109|Refrigerator|        38000|
# |      P110|        Sofa|        32000|
# |      P107|       Watch|        24000|
# +----------+------------+-------------+

# %%
#75
spark.sql("SELECT payment_mode,SUM(sale_amount) AS total_revenue FROM sales GROUP BY payment_mode;").show()
# Out:
# +------------+-------------+
# |payment_mode|total_revenue|
# +------------+-------------+
# |        Card|       133000|
# |        Cash|        35500|
# |Not Provided|        14000|
# |         UPI|       190500|
# +------------+-------------+

# %% [markdown]
# **Full Refresh and Incremental Load**

# %%
#76
retail.drop("data_quality_status").write.mode("overwrite").parquet("gold/sales")
retail_paraquet = spark.read.parquet("gold/sales")
retail_paraquet.show()
# Out:
# +----------+--------+-------+----------+-------------+-----------+------------+--------------------+---------+-----------+-----------+------------+------------+-----------+------------+-----------+----------+
# |product_id|store_id|sale_id| sale_date|quantity_sold|sale_amount|payment_mode|          store_name|     city|      state| store_type|manager_name|product_name|   category|       brand|supplier_id|unit_price|
# +----------+--------+-------+----------+-------------+-----------+------------+--------------------+---------+-----------+-----------+------------+------------+-----------+------------+-----------+----------+
# |      P101|    S101| SA1001|2026-01-10|            1|      65000|         UPI|Metro Mart Hyderabad|Hyderabad|  Telangana|Supermarket|Rahul Sharma|      Laptop|Electronics|      Lenovo|       S201|     65000|
# ...

# %%
#77
sales.write.mode("overwrite").partitionBy("year","month").parquet("gold/sales")
sales_paraquet = spark.read.parquet("gold/sales")
sales_paraquet.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+----+-----+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|year|month|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+----+-----+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|2026|    1|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|2026|    1|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|2026|    1|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|2026|    1|
# ...

# %%
#78

data = [
    ("SA1016", "S101", "P101", "2026-03-01", 1, 65000, "UPI"),
    ("SA1017", "S102", "P103", "2026-03-02", 1, 45000, "Card"),
    ("SA1018", "S105", "P108", "2026-03-03", 2, 5000, "Cash")
]
columns = ["sale_id","store_id","product_id","sale_date","quantity_sold","sale_amount","payment_mode"]
march_sales = spark.createDataFrame(data, columns)
march_sales.write.mode("overwrite").option("header", True).csv("incremental_sales_march")

# %%
#79
march_df = spark.read.csv("incremental_sales_march",header=True,inferSchema=True)
march_df.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|
# +-------+--------+----------+----------+-------------+-----------+------------+
# | SA1017|    S102|      P103|2026-03-02|            1|      45000|        Card|
# | SA1018|    S105|      P108|2026-03-03|            2|       5000|        Cash|
# | SA1016|    S101|      P101|2026-03-01|            1|      65000|         UPI|
# +-------+--------+----------+----------+-------------+-----------+------------+

# %%
#80
march_df.write.mode("append").parquet("silver/sales")
march_paraquet = spark.read.parquet("silver/sales")
march_paraquet.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|
# | SA1005|    S104|      P107|2026-01-12|            1|       8000|        Card|              Valid|
# | SA1006|    S105|      P108|2026-01-13|            5|      12500|         UPI|              Valid|
# ...

# %%
#81
updated_sales = spark.read.parquet("silver/sales")
updated_sales.groupBy("product_id").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +----------+-------------+
# |product_id|total_revenue|
# +----------+-------------+
# |      P110|        32000|
# |      P105|        12000|
# |      P102|        75000|
# |      P106|        18000|
# |      P107|        24000|
# |      P120|        10000|
# |      P103|        90000|
# |      P109|        38000|
# |      P104|        14000|
# |      P101|       260000|
# |      P108|        30000|
# +----------+-------------+

# %%
#82
updated_sales.groupBy("store_id").agg(sum("sale_amount").alias("total_revenue")).show()
# Out:
# +--------+-------------+
# |store_id|total_revenue|
# +--------+-------------+
# |    S105|        30000|
# |    S102|       155000|
# |    S106|        38000|
# |    S104|        24000|
# |    S107|        32000|
# |    S101|       284000|
# |    S108|        10000|
# |    S103|        30000|
# +--------+-------------+

# %%
#83
sales.write.mode("overwrite").partitionBy("year","month").parquet("gold/sales")
sales_paraquet = spark.read.parquet("gold/sales")
sales_paraquet.show()
# Out:
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+----+-----+
# |sale_id|store_id|product_id| sale_date|quantity_sold|sale_amount|payment_mode|data_quality_status|revenue_category|year|month|
# +-------+--------+----------+----------+-------------+-----------+------------+-------------------+----------------+----+-----+
# | SA1001|    S101|      P101|2026-01-10|            1|      65000|         UPI|              Valid|    High Revenue|2026|    1|
# | SA1002|    S101|      P102|2026-01-10|            2|      50000|        Card|              Valid|    High Revenue|2026|    1|
# | SA1003|    S102|      P101|2026-01-11|            1|      65000|         UPI|              Valid|    High Revenue|2026|    1|
# | SA1004|    S103|      P106|2026-01-12|            4|      18000|        Cash|              Valid|  Medium Revenue|2026|    1|
# ...

# %%
#84
before_count = sales.count()
after_count = spark.read.parquet("silver/sales").count()
print("Before Incremental Load :", before_count)
print("After Incremental Load  :", after_count)
print("New Records Added       :", after_count - before_count)
# Out:
# Before Incremental Load : 15
# After Incremental Load  : 21
# New Records Added       : 6

# %% [markdown]
# **Final Gold Reports**

# %%
#85
store_report = retail.groupBy("store_id","store_name","city","state").agg(sum("quantity_sold").alias("total_sales"),sum("sale_amount").alias("total_revenue"))
store_report.show()
# Out:
# +--------+--------------------+---------+-----------+-----------+-------------+
# |store_id|          store_name|     city|      state|total_sales|total_revenue|
# +--------+--------------------+---------+-----------+-----------+-------------+
# |    S106|     Metro Mart Pune|     Pune|Maharashtra|          1|        38000|
# |    S107|    Metro Mart Kochi|    Kochi|     Kerala|          1|        32000|
# |    S101|Metro Mart Hyderabad|Hyderabad|  Telangana|          6|       154000|
# |    S103|   Metro Mart Mumbai|   Mumbai|Maharashtra|          5|        30000|
# |    S105|    Metro Mart Delhi|    Delhi|      Delhi|          8|        20000|
# |    S102|Metro Mart Bangalore|Bangalore|  Karnataka|          2|        65000|
# |    S104|  Metro Mart Chennai|  Chennai| Tamil Nadu|          3|        24000|
# |    S108|   Metro Mart Jaipur|   Jaipur|  Rajasthan|          2|        10000|
# +--------+--------------------+---------+-----------+-----------+-------------+

# %%
#86
product_report = retail.groupBy("product_id","product_name","category","brand").agg(sum("quantity_sold").alias("total_quantity_sold"),sum("sale_amount").alias("total_revenue"))
product_report.show()
# Out:
# +----------+------------+-----------+------------+-------------------+-------------+
# |product_id|product_name|   category|       brand|total_quantity_sold|total_revenue|
# +----------+------------+-----------+------------+-------------------+-------------+
# |      P110|        Sofa|  Furniture|      Godrej|                  1|        32000|
# |      P104|Office Chair|  Furniture| Featherlite|                  2|        14000|
# |      P101|      Laptop|Electronics|      Lenovo|                  2|       130000|
# |      P109|Refrigerator|Electronics|   Whirlpool|                  1|        38000|
# |      P105| Study Table|  Furniture|Urban Ladder|                  1|        12000|
# |      P107|       Watch|    Fashion|    Fastrack|                  3|        24000|
# |      P102|      Mobile|Electronics|     Samsung|                  3|        75000|
# |      P108|    Backpack|    Fashion|   Wildcraft|                  8|        20000|
# ...

# %%
#87
inventory_report = inve_prod.select("store_id","product_id","product_name","stock_quantity","reorder_level","stock_status")
inventory_report.show()
# Out:
# +--------+----------+------------+--------------+-------------+----------------+
# |store_id|product_id|product_name|stock_quantity|reorder_level|    stock_status|
# +--------+----------+------------+--------------+-------------+----------------+
# |    S101|      P101|      Laptop|            10|            5|Sufficient Stock|
# |    S101|      P102|      Mobile|            25|           10|Sufficient Stock|
# |    S101|      P104|Office Chair|             3|            5|Reorder Required|
# |    S102|      P101|      Laptop|             8|            5|Sufficient Stock|
# |    S102|      P103|  Television|             5|            4|Sufficient Stock|
# |    S103|      P105| Study Table|             2|            5|Reorder Required|
# |    S103|      P106|       Shoes|            30|           10|Sufficient Stock|
# |    S104|      P107|       Watch|             4|            5|Reorder Required|
# |    S105|      P108|    Backpack|            50|           20|Sufficient Stock|
# ...

# %%
#88
supplier_report = suppliers_flat.select("supplier_id","supplier_name","city","rating","supplier_quality","phone","email")
supplier_report.show()
# Out:
# +-----------+--------------------+---------+------+----------------+------------+--------------------+
# |supplier_id|       supplier_name|     city|rating|supplier_quality|       phone|               email|
# +-----------+--------------------+---------+------+----------------+------------+--------------------+
# |       S201|    TechSource India|Hyderabad|   4.5|       Excellent|  9876500011| techsource@mail.com|
# |       S202|MobileWorld Distr...|Bangalore|   4.2|            Good|Not Provided|mobileworld@mail.com|
# |       S203|     HomeTech Supply|   Mumbai|   4.4|            Good|  9876500013|        Not Provided|
# |       S204|  Urban Furniture Co|    Delhi|   4.0|            Good|  9876500014|      urban@mail.com|
# |       S205|      Fashion Direct|     Pune|   3.8|         Average|Not Provided|        Not Provided|
# +-----------+--------------------+---------+------+----------------+------------+--------------------+

# %%
#89
from pyspark.sql.functions import countDistinct

category_report = retail.groupBy("category").agg(countDistinct("product_id").alias("total_products"),sum("quantity_sold").alias("total_quantity_sold"),sum("sale_amount").alias("total_revenue"))
category_report.show()
# Out:
# +-----------+--------------+-------------------+-------------+
# |   category|total_products|total_quantity_sold|total_revenue|
# +-----------+--------------+-------------------+-------------+
# |    Fashion|             3|                 15|        62000|
# |       NULL|             1|                  2|        10000|
# |Electronics|             4|                  7|       243000|
# |  Furniture|             3|                  4|        58000|
# +-----------+--------------+-------------------+-------------+

# %%
#90
payment_report = sales.groupBy( "payment_mode").agg(count("*").alias("total_transactions"),sum("sale_amount").alias("total_revenue"))
payment_report.show()
# Out:
# +------------+------------------+-------------+
# |payment_mode|total_transactions|total_revenue|
# +------------+------------------+-------------+
# |        Card|                 5|       133000|
# |        Cash|                 3|        35500|
# |Not Provided|                 1|        14000|
# |         UPI|                 6|       190500|
# +------------+------------------+-------------+
