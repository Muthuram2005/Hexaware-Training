# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
.appName("PySpark Exercise2") \
.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://bfc590e25c9d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark Exercise2</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [
(1, "Rahul Sharma", "Hyderabad", "Electronics", "Laptop", 1, 65000, "Cancelled"),
(2, "Priya Reddy", "Bangalore", "Electronics", "Mobile", 2, 25000, "Delivered"),
(3, "Amit Kumar", "Mumbai", "Furniture", "Chair", 4, 3500, "Pending"),
(4, "Sneha Patel", "Chennai", "Electronics", "Tablet", 1, 30000, "Cancelled"),
(5, "Farhan Ali", "Delhi", "Furniture", "Table", 2, 12000, "Delivered"),
(6, "Neha Singh", "Hyderabad", "Fashion", "Shoes", 3, 2500, "Delivered"),
(7, "Arjun Verma", "Pune", "Fashion", "Watch", 1, 8000, "Pending"),
(8, "Meera Nair", "Bangalore", "Electronics", "TV", 1, 45000, "Delivered"),
(9, "Kiran Rao", "Hyderabad", "Furniture", "Desk", 1, 15000, "Delivered"),
(10, "Ravi Kumar", "Mumbai", "Electronics", "Mobile", 1, 28000, "Delivered")
]
columns = [
"order_id",
"customer_name",
"city",
"category",
"product",
"quantity",
"price",
"order_status"
]
df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# ...

# %%
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# ...

# %%
df.select("customer_name","city","product").show()
# Out:
# +-------------+---------+-------+
# |customer_name|     city|product|
# +-------------+---------+-------+
# | Rahul Sharma|Hyderabad| Laptop|
# |  Priya Reddy|Bangalore| Mobile|
# |   Amit Kumar|   Mumbai|  Chair|
# |  Sneha Patel|  Chennai| Tablet|
# |   Farhan Ali|    Delhi|  Table|
# |   Neha Singh|Hyderabad|  Shoes|
# |  Arjun Verma|     Pune|  Watch|
# |   Meera Nair|Bangalore|     TV|
# |    Kiran Rao|Hyderabad|   Desk|
# |   Ravi Kumar|   Mumbai| Mobile|
# +-------------+---------+-------+

# %%
df.select("product","price").show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | Laptop|65000|
# | Mobile|25000|
# |  Chair| 3500|
# | Tablet|30000|
# |  Table|12000|
# |  Shoes| 2500|
# |  Watch| 8000|
# |     TV|45000|
# |   Desk|15000|
# | Mobile|28000|
# +-------+-----+

# %%
df.filter(df.city == "Hyderabad").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.city == "Bangalore").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.category == "Electronics").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.category == "Furniture").show()
# Out:
# +--------+-------------+---------+---------+-------+--------+-----+------------+
# |order_id|customer_name|     city| category|product|quantity|price|order_status|
# +--------+-------------+---------+---------+-------+--------+-----+------------+
# |       3|   Amit Kumar|   Mumbai|Furniture|  Chair|       4| 3500|     Pending|
# |       5|   Farhan Ali|    Delhi|Furniture|  Table|       2|12000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|Furniture|   Desk|       1|15000|   Delivered|
# +--------+-------------+---------+---------+-------+--------+-----+------------+

# %%
df.filter(df.price > 30000).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.quantity > 1).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.order_status == "Delivered").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.order_status == "Pending").show()
# Out:
# +--------+-------------+------+---------+-------+--------+-----+------------+
# |order_id|customer_name|  city| category|product|quantity|price|order_status|
# +--------+-------------+------+---------+-------+--------+-----+------------+
# |       3|   Amit Kumar|Mumbai|Furniture|  Chair|       4| 3500|     Pending|
# |       7|  Arjun Verma|  Pune|  Fashion|  Watch|       1| 8000|     Pending|
# +--------+-------------+------+---------+-------+--------+-----+------------+

# %%
df.filter(df.order_status == "Cancelled").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.city.isin("Hyderabad","Mumbai")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.category.isin("Electronics","Fashion")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.filter(df.price.between(10000,50000)).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+

# %%
df.orderBy("price").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# ...

# %%
df.orderBy(df.price.desc()).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|
# ...

# %%
df.orderBy("city","price").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|
# ...

# %%
df = df.withColumn("total_amount", df.quantity * df.price)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|
# ...

# %%
df = df.withColumn("discount", df.total_amount * 0.10)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|
# ...

# %%
df = df.withColumn("final_amount", df.total_amount - df.discount)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df.withColumnRenamed("customer_name", "customer").show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|    customer|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|  Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df.withColumnRenamed("order_status", "status").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|Cancelled|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
from pyspark.sql.functions import *
df.agg(sum(df.final_amount).alias("total_revenue")).show()
# Out:
# +-------------+
# |total_revenue|
# +-------------+
# |     257850.0|
# +-------------+

# %%
df.agg(avg(df.final_amount).alias("average_order_value")).show()
# Out:
# +-------------------+
# |average_order_value|
# +-------------------+
# |            25785.0|
# +-------------------+

# %%
df.agg(max(df.final_amount).alias("highest_order_value")).show()
# Out:
# +-------------------+
# |highest_order_value|
# +-------------------+
# |            58500.0|
# +-------------------+

# %%
df.agg(min(df.final_amount).alias("Lowest_order_value")).show()
# Out:
# +------------------+
# |Lowest_order_value|
# +------------------+
# |            6750.0|
# +------------------+

# %%
df.count()
# Out:
# 10

# %%
df.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |    Delhi|    1|
# |Hyderabad|    3|
# |     Pune|    1|
# +---------+-----+

# %%
df.groupBy("category").count().show()
# Out:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# |Electronics|    5|
# |  Furniture|    3|
# |    Fashion|    2|
# +-----------+-----+

# %%
df.groupBy("order_status").count().show()
# Out:
# +------------+-----+
# |order_status|count|
# +------------+-----+
# |   Cancelled|    2|
# |   Delivered|    6|
# |     Pending|    2|
# +------------+-----+

# %%
df.groupBy("city").agg(sum("total_amount").alias("total_revenue")).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|        95000|
# |  Chennai|        30000|
# |   Mumbai|        42000|
# |    Delhi|        24000|
# |Hyderabad|        87500|
# |     Pune|         8000|
# +---------+-------------+

# %%
df.groupBy("category").agg(sum("total_amount").alias("total_revenue")).show()
# Out:
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# |Electronics|       218000|
# |  Furniture|        53000|
# |    Fashion|        15500|
# +-----------+-------------+

# %%
df.groupBy("product").agg(sum("total_amount").alias("total_revenue")).show()
# Out:
# +-------+-------------+
# |product|total_revenue|
# +-------+-------------+
# |  Chair|        14000|
# | Laptop|        65000|
# |  Table|        24000|
# | Mobile|        78000|
# | Tablet|        30000|
# |     TV|        45000|
# |   Desk|        15000|
# |  Shoes|         7500|
# |  Watch|         8000|
# +-------+-------------+

# %%
df.groupBy("category").agg(avg("price").alias("average_price")).show()
# Out:
# +-----------+------------------+
# |   category|     average_price|
# +-----------+------------------+
# |Electronics|           38600.0|
# |  Furniture|10166.666666666666|
# |    Fashion|            5250.0|
# +-----------+------------------+

# %%
df.groupBy("category").agg(max("price").alias("maximum_price")).show()
# Out:
# +-----------+-------------+
# |   category|maximum_price|
# +-----------+-------------+
# |Electronics|        65000|
# |  Furniture|        15000|
# |    Fashion|         8000|
# +-----------+-------------+

# %%
df.groupBy("category").agg(min("price").alias("minimum_price")).show()
# Out:
# +-----------+-------------+
# |   category|minimum_price|
# +-----------+-------------+
# |Electronics|        25000|
# |  Furniture|         3500|
# |    Fashion|         2500|
# +-----------+-------------+

# %%
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |  Chennai|
# |   Mumbai|
# |    Delhi|
# |Hyderabad|
# |     Pune|
# +---------+

# %%
df.select("category").distinct().show()
# Out:
# +-----------+
# |   category|
# +-----------+
# |Electronics|
# |  Furniture|
# |    Fashion|
# +-----------+

# %%
df.select("order_status").distinct().show()
# Out:
# +------------+
# |order_status|
# +------------+
# |   Cancelled|
# |   Delivered|
# |     Pending|
# +------------+

# %%
df.orderBy(df.total_amount.desc()).limit(3).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %%
df.orderBy("total_amount").limit(1).show()
# Out:
# +--------+-------------+---------+--------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+--------+-------+--------+-----+------------+------------+--------+------------+
# |       6|   Neha Singh|Hyderabad| Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# +--------+-------------+---------+--------+-------+--------+-----+------------+------------+--------+------------+

# %%
df.filter(df.product.startswith("M")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %%
df.filter(df.customer_name.contains("a")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# ...

# %%
df.filter(df.product.contains("o")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %%
df = df.withColumn("order_value_category", when(col("total_amount") >= 50000, "High")
.when(col("total_amount") >= 20000, "Medium")
.otherwise("Low")
)
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|order_value_category|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Cancelled|       65000|  6500.0|     58500.0|                High|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|                High|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|                 Low|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|              Medium|
# ...

# %%
df.groupBy("order_value_category").count().show()
# Out:
# +--------------------+-----+
# |order_value_category|count|
# +--------------------+-----+
# |                High|    2|
# |                 Low|    4|
# |              Medium|    4|
# +--------------------+-----+

# %%
df.filter(df.order_status == "Delivered") \
.select("order_id", "customer_name", "final_amount") \
.show()
# Out:
# +--------+-------------+------------+
# |order_id|customer_name|final_amount|
# +--------+-------------+------------+
# |       2|  Priya Reddy|     45000.0|
# |       5|   Farhan Ali|     21600.0|
# |       6|   Neha Singh|      6750.0|
# |       8|   Meera Nair|     40500.0|
# |       9|    Kiran Rao|     13500.0|
# |      10|   Ravi Kumar|     25200.0|
# +--------+-------------+------------+

# %%
df.filter(df.order_status == "Delivered") \
.groupBy("city") \
.sum("final_amount") \
.show()
# Out:
# +---------+-----------------+
# |     city|sum(final_amount)|
# +---------+-----------------+
# |Bangalore|          85500.0|
# |    Delhi|          21600.0|
# |   Mumbai|          25200.0|
# |Hyderabad|          20250.0|
# +---------+-----------------+

# %%
df.select("order_id","customer_name","city","category","product","quantity","price","total_amount","discount","final_amount","order_status").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+--------+------------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|total_amount|discount|final_amount|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+--------+------------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|       65000|  6500.0|     58500.0|   Cancelled|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|       50000|  5000.0|     45000.0|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|       14000|  1400.0|     12600.0|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|       30000|  3000.0|     27000.0|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|       24000|  2400.0|     21600.0|   Delivered|
# ...
